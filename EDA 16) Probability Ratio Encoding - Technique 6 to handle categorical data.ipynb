# %% [markdown]
# ### EDA : Feature Engineering
# # Types of Encoding to handle Categorical Data
# Video 1) One Hot Encoding - Technique To handle Variables with multiple categories
#
# Video 2) Count or Frequency Encoding
#
# Video 3) Ordinal Number Encoding or Label Encoding
#
# Video 14) Target Guided Ordinal Encoding
#
# Video 15) Mean Encoding
#
# Video 16) Probability Ratio Encoding

# %% [markdown]
# # Probability Ratio Encoding
# Steps
# 1) Calculate probability of "Survived" wrt "Cabin" which is a categorical feature
#
# 2) Calculate probability of "Died" wrt "Cabin" which is a categorical feature
#
# 3) Calculate probability of "Survived" / prob"Died"
#
# 4) Create a Dictionary to map cabin with probability
#
# 5) Replace with the categorical features / values

# %%
import pandas as pd

df = pd.read_csv('titanic_train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import pandas as pd

df = pd.read_csv('titanic_train.csv',usecols=['Cabin', 'Survived'])
df
# Out:
#      Survived Cabin
# 0           0   NaN
# 1           1   C85
# 2           1   NaN
# 3           1  C123
# 4           0   NaN
# ..        ...   ...
# 886         0   NaN
# 887         1   B42
# 888         0   NaN
# 889         1  C148
# 890         0   NaN
#
# [891 rows x 2 columns]

# %%
# Replacing Nan values with "Missing" in the column "Cabin"
df['Cabin'].fillna('Missing',inplace=True)
df
# Out:
#      Survived    Cabin
# 0           0  Missing
# 1           1      C85
# 2           1  Missing
# 3           1     C123
# 4           0  Missing
# ..        ...      ...
# 886         0  Missing
# 887         1      B42
# 888         0  Missing
# 889         1     C148
# 890         0  Missing
#
# [891 rows x 2 columns]

# %%
df['Cabin'].unique() # List of Unique categories in the column / feature "Cabin"
# Out:
# array(['Missing', 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
# extracting the first letter
# to create blocks e.g - C,B,E , etc

df['Cabin'] = df['Cabin'].astype(str).str[0]
df
# Out:
#      Survived Cabin
# 0           0     M
# 1           1     C
# 2           1     M
# 3           1     C
# 4           0     M
# ..        ...   ...
# 886         0     M
# 887         1     B
# 888         0     M
# 889         1     C
# 890         0     M
#
# [891 rows x 2 columns]

# %%
#Method 1
df['Cabin'].unique() # List of Unique categories in the column / feature "Cabin"
# Out:
# array(['M', 'C', 'E', 'G', 'D', 'A', 'B', 'F', 'T'], dtype=object)

# %%
#Method 2
df.Cabin.unique() # List of Unique categories in the column / feature "Cabin"
# Out:
# array(['M', 'C', 'E', 'G', 'D', 'A', 'B', 'F', 'T'], dtype=object)

# %%
# defniing probability dataframe
prob_df = df.groupby(['Cabin'])['Survived'].mean() # calculating the "Survived" probability of person in each "cabin"/block
prob_df
# Out:
# Cabin
# A    0.466667
# B    0.744681
# C    0.593220
# D    0.757576
# E    0.750000
# F    0.615385
# G    0.500000
# M    0.299854
# T    0.000000
# Name: Survived, dtype: float64

# %%
prob_df = pd.DataFrame(prob_df) #converting the data in Dataframe
prob_df #changed the values in the column "Survived"
# Out:
#        Survived
# Cabin
# A      0.466667
# B      0.744681
# C      0.593220
# D      0.757576
# E      0.750000
# F      0.615385
# G      0.500000
# M      0.299854
# T      0.000000

# %%
# Calculating the probability that the person has died
prob_df['Died'] = 1 - prob_df['Survived']
prob_df
# Out:
#        Survived      Died
# Cabin
# A      0.466667  0.533333
# B      0.744681  0.255319
# C      0.593220  0.406780
# D      0.757576  0.242424
# E      0.750000  0.250000
# F      0.615385  0.384615
# G      0.500000  0.500000
# M      0.299854  0.700146
# T      0.000000  1.000000

# %% [markdown]
# # Probability Ratio = prob(Survived) / prob(died)

# %%
# Calculating the probability ratio
prob_df['Probability_Ratio'] = prob_df['Survived'] / prob_df['Died']
prob_df
# Out:
#        Survived      Died  Probability_Ratio
# Cabin
# A      0.466667  0.533333           0.875000
# B      0.744681  0.255319           2.916667
# C      0.593220  0.406780           1.458333
# D      0.757576  0.242424           3.125000
# E      0.750000  0.250000           3.000000
# F      0.615385  0.384615           1.600000
# G      0.500000  0.500000           1.000000
# M      0.299854  0.700146           0.428274
# T      0.000000  1.000000           0.000000

# %%
# Converting the probability ratio into Dictionary
probability_encoded = prob_df['Probability_Ratio'].to_dict()
probability_encoded
# Out:
# {'A': 0.875,
#  'B': 2.916666666666666,
#  'C': 1.4583333333333333,
#  'D': 3.125,
#  'E': 3.0,
#  'F': 1.6000000000000003,
#  'G': 1.0,
#  'M': 0.42827442827442824,
#  'T': 0.0}

# %%
# creating New column to map "probability_encoded" with "Cabin"
df['Cabin_encoded'] = df['Cabin'].map(probability_encoded)
df
# Out:
#      Survived Cabin  Cabin_encoded
# 0           0     M       0.428274
# 1           1     C       1.458333
# 2           1     M       0.428274
# 3           1     C       1.458333
# 4           0     M       0.428274
# ..        ...   ...            ...
# 886         0     M       0.428274
# 887         1     B       2.916667
# 888         0     M       0.428274
# 889         1     C       1.458333
# 890         0     M       0.428274
#
# [891 rows x 3 columns]

# %% [markdown]
# # Advantage
# 1) Easy to imlement
#
# 2) "Cabin_encoded" in numerical value is more useful than "Cabin" in categorical values

# %% [markdown]
# # Feature Scaling: Standardization Vs Normalization
